# %%
import pandas as pd

# %%
###################realizando el objeto series-------------------
s=pd.Series([1,2,3],index=['a','b','c'])
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
####acceder por etiqueta
s.loc['a']
# Out:
# 1

# %%
###### acceder por indice
s.iloc[1]
# Out:
# 2

# %%
### pasando un diccionario a serie
data = {"a":1, "b":2, "c":3}
s= pd.Series(data)
s
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
###sumandole un numero a la serie
s+2
# Out:
# a    3
# b    4
# c    5
# dtype: int64

# %%
s**2
# Out:
# a    1
# b    4
# c    9
# dtype: int64

# %%
import numpy as np ####metiendo la serie ya que pandas soperte nupy sin problema

np.exp(s)
# Out:
# a     2.718282
# b     7.389056
# c    20.085537
# dtype: float64

# %%
####escoger los dos ultimos numeros
s[-2:] #dame los dos primeros dos numeros desde el final hasta el final
# Out:
# b    2
# c    3
# dtype: int64

# %%
### filtrado
s[s >=2]
# Out:
# b    2
# c    3
# dtype: int64

# %%
s2 =  pd.Series({"a":1, "b":2, "c":3})
s3  = pd.Series({"a":1, "b":2, "c":3})

# %%
s2+s3   ####si tienen el mismo valor se suman pero los que no no los suman NaN(no es un numero)
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
#####visualizacionnnn

# %matplotlib inline

import matplotlib.pyplot as plt
temperatures = [4.4,5.1,6.1,6.2,6.1,6.1,5.7,5.2,4.7,4.1,3.9,3.5]
s = pd.Series(temperatures, name="Temperature")
s.plot()
plt.show()

# %%
#### OBJETO DATA_FRAME######

# %%
#### de una serie a un data frame

data = {
    "weight": pd.Series([68, 83, 112], index=["alice", "bob", "charles"]),
    "birthyear": pd.Series([1984, 1985, 1992], index=["bob", "alice", "charles"], name="year"),
    "children": pd.Series([0, 3], index=["charles", "bob"]),
    "hobby": pd.Series(["Biking", "Dancing"], index=["alice", "bob"]),
}


df= pd.DataFrame(data)
df
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
#### de un diccionario a un dataframe directamente el df.diccio
df = pd.DataFrame({
    "birthyear": {"alice":1985, "bob": 1984, "charles": 1992},
    "hobby": {"alice":"Biking", "bob": "Dancing"},
    "weight": {"alice":68, "bob": 83, "charles": 112},
    "children": {"bob": 3, "charles": 0}
})

df
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
### accediendo los valores a varias columnas

# %%
df[["weight","birthyear"]]
# Out:
#          weight  birthyear
# alice        68       1985
# bob          83       1984
# charles     112       1992

# %%
###accediendo al valor de una columna

df.loc["alice"]
# Out:
# birthyear      1985
# hobby        Biking
# weight           68
# children        NaN
# Name: alice, dtype: object

# %%
#indexamos con la posicion
df.iloc[0]
# Out:
# birthyear      1985
# hobby        Biking
# weight           68
# children        NaN
# Name: alice, dtype: object

# %%
##### agregando nueva columna columnasss


df["height"] = pd.Series({"alice":167,"bob":180})
df
# Out:
#          birthyear    hobby  weight  children  height
# alice         1985   Biking      68       NaN   167.0
# bob           1984  Dancing      83       3.0   180.0
# charles       1992      NaN     112       0.0     NaN

# %%
####### eliminando columna
del df["height"]

df
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
####### añadir columna en unqa posiscion en especifico 

df.insert(2,"heigth", pd.Series({"alice":167,"bob":180}))

df
# Out:
#          birthyear    hobby  heigth  weight  children
# alice         1985   Biking   167.0      68       NaN
# bob           1984  Dancing   180.0      83       3.0
# charles       1992      NaN     NaN     112       0.0

# %%
#### nueva columna a partir de otras columnas   
df["w2h_ratio"] = df["weight"] / df["heigth"]
df
# Out:
#          birthyear    hobby  heigth  weight  children  w2h_ratio
# alice         1985   Biking   167.0      68       NaN   0.407186
# bob           1984  Dancing   180.0      83       3.0   0.461111
# charles       1992      NaN     NaN     112       0.0        NaN

# %%
df=df[["weight","heigth"]]
df
# Out:
#          weight  heigth
# alice        68   167.0
# bob          83   180.0
# charles     112     NaN

# %%
df +2
# Out:
#          weight  heigth
# alice        70   169.0
# bob          85   182.0
# charles     114     NaN

# %%
###pasando data frama numpy directamente, esto se puedo por lo dicho anteriormente
np.exp(df)
# Out:
#                weight        heigth
# alice    3.404276e+29  3.366499e+72
# bob      1.112864e+36  1.489384e+78
# charles  4.375039e+48           NaN

# %%
###### filtrado del dataframe de esta forma se puede ###aqui nos devuelven todas las columnas ojo con eso
df[df["weight"]> 80]
# Out:
#          weight  heigth
# bob          83   180.0
# charles     112     NaN

# %%
df[(df["weight"]>80) & (df["heigth"] >= 180)]
# Out:
#      weight  heigth
# bob      83   180.0

# %%
df.plot
plt.show()
