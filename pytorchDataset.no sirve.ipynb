# %%
import torch

D_in, H, D_out = 784, 100, 10

model = torch.nn.Sequential(
    torch.nn.Linear(D_in, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, D_out),
)

# %%
'sacando outputs'

outputs = model(torch.rand(64,784))   #064 imagenes con sus inputs
outputs.shape
# Out:
# torch.Size([64, 10])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
#enviando a la GPU

model.to("cuda")
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
import sklearn
from sklearn.datasets import fetch_openml

#descarga de datos

mnist= fetch_openml('mnist_784', version=1)
X, Y = mnist["data"], mnist["target"]

X.shape, Y.shape
# Out:
# ((70000, 784), (70000,))

# %%
import numpy as np

#normalizacion y spliteo

X_train, X_test, Y_train, Y_test=  X[:60000]/255., X[60000:]/255.,Y[:60000].astype(np.int), Y[60000:].astype(np.int)

# %%
class Dataset(torch.utils.data.Dataset):

  def __init__(self,X,Y):
    self.X=torch.from_numpy(X).float().cuda()
    self.Y=torch.from_numpy(Y),long().cuda()

  def __len__(self):
      return len(self.X)
  def __getitem__(self, ix):
      return self.X[ix], self.Y[ix]

# %%
dataloader = torch.utils.data.DataLoader(dataset, batch_size=100, shuffle=True)

x, y = next(iter(dataloader))

x.shape, y.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-946e66004bb9> in <module>()
# ----> 1 dataloader = torch.utils.data.DataLoader(dataset, batch_size=100, shuffle=True)
#       2
#       3 x, y = next(iter(dataloader))
#       4
#       5 x.shape, y.shape
#
# NameError: name 'dataset' is not defined

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.8)

# %%
epochs = 10
log_each = 1
l = []
model.train()
for e in range(1, epochs+1): 
    
    _l = []
    # iteramos por batches en el dataloader
    for x_b, y_b in dataloader:
        
        # forward
        y_pred = model(x_b)

        # loss
        loss = criterion(y_pred, y_b)
        _l.append(loss.item())

        # ponemos a cero los gradientes
        optimizer.zero_grad()

        # Backprop (calculamos todos los gradientes automáticamente)
        loss.backward()

        # update de los pesos
        optimizer.step()
    
    l.append(np.mean(_l))
    if not e % log_each:
        print(f"Epoch {e}/{epochs} Loss {np.mean(l):.5f}")
        
y_pred = evaluate(torch.from_numpy(X_test).float().cuda())
accuracy_score(y_test, y_pred.cpu().numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-4bd319697fb2> in <module>()
#       7     _l = []
#       8     # iteramos por batches en el dataloader
# ----> 9     for x_b, y_b in dataloader:
#      10
#      11         # forward
#
# NameError: name 'dataloader' is not defined
