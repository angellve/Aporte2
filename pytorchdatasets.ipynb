# %%
import torch
import sklearn

D_in, H, D_out = 784, 100, 10

model = torch.nn.Sequential(
    torch.nn.Linear(D_in, H),
    torch.nn.ReLU(),
    torch.nn.Linear(H, D_out),
)

# %%
model.to("cuda")
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
from sklearn.datasets import fetch_openml

# descarga datos

mnist = fetch_openml('mnist_784', version=1)
X, Y = mnist["data"], mnist["target"]

X.shape, Y.shape
# Out:
# ((70000, 784), (70000,))

# %%
import numpy as np

# normalización y split

X_train, X_test, y_train, y_test = X[:60000] / 255., X[60000:] / 255., Y[:60000].astype(np.int), Y[60000:].astype(np.int)

# %% [markdown]
# tipo 1 dataset

# %%
'''clase dataser, hereda de la clase 'torch.uyils.data.datase'
class Dataset(torch.utils.data.Dataset):

  #constructor 
  def __init__(self,X,Y):
    self.X= torch.from_numpy(X).float().cuda()
    self.Y= torch.from_numpy(Y).long().cuda()
  #devolvemos el numero de datos del dataset
  def __len__(self):
    return len(self.X)
  #devolcemos el elemento 'ix' del dataset
  def __getitem__(self,ix):
    return self.X[ix], self.Y[ix]'''

# %% [markdown]
# tipo 2 dataset

# %%
dataloader=torch.utils.data.DataLoader(dataset,batch_size=100, shuffle=True)
x, y = next(iter(dataloader))
x.shape, y.shape
# Out:
# (torch.Size([100, 784]), torch.Size([100]))

# %%
def softmax(x):
    return torch.exp(x) / torch.exp(x).sum(axis=-1,keepdims=True)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.8)

# %% [markdown]
# # ***`[aqui esta lo que se hace michibatches]
# `***

# %%
epochs = 10
log_each = 1
l = []
model.train()
batches = len(dataset) // batch_size
for e in range(1, epochs+1): 
    
    _l = []
    # iteramos por batches en el dataset
    for b in range(batches):
       for x_b, y_b in dataloader:
        
        # forward
        y_pred = model(x_b)

        # loss
        loss = criterion(y_pred, y_b)
        _l.append(loss.item())

        # ponemos a cero los gradientes
        optimizer.zero_grad()

        # Backprop (calculamos todos los gradientes automáticamente)
        loss.backward()

        # update de los pesos
        optimizer.step()
    
    l.append(np.mean(_l))
    if not e % log_each:
        print(f"Epoch {e}/{epochs} Loss {np.mean(l):.5f}")
        
y_pred = evaluate(torch.from_numpy(X_test).float().cuda())
accuracy_score(y_test, y_pred.cpu().numpy())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-78-a8fd45de7165> in <module>()
#      15
#      16         # loss
# ---> 17         loss = criterion(y_pred, y_b)
#      18         _l.append(loss.item())
#      19
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#    1046         assert self.weight is None or isinstance(self.weight, Tensor)
#    1047         return F.cross_entropy(input, target, weight=self.weight,
# ...

# %%
from sklearn.metrics import accuracy_score

def evaluate(x):
    model.eval()
    y_pred = model(x)
    y_probas = softmax(y_pred)
    return torch.argmax(y_probas, axis=1)

y_pred = evaluate(torch.from_numpy(X_test).float().cuda())
accuracy_score(y_test, y_pred.cpu().numpy())
# Out:
# 0.926

# %% [markdown]
# ejemplo de la clase data sets

# %%
# Out:
# 60000
